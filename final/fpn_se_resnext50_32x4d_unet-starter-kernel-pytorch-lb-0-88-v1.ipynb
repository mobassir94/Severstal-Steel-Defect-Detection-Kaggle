# %% [markdown]
# ## UNet starter for Steel defect detection challenge
#
#
# This kernel uses a UNet model with pretrained resnet18 encoder for this challenge, with simple augmentations using albumentations library, uses BCE loss, metrics like Dice and IoU. I've used [segmentation_models.pytorch](https://github.com/qubvel/segmentation_models.pytorch) which comes with a lot pre-implemented segmentation architectures. This is a modified version of my previous [kernel](https://www.kaggle.com/rishabhiitbhu/unet-with-resnet34-encoder-pytorch) for [siim-acr-pneumothorax-segmentation](https://www.kaggle.com/c/siim-acr-pneumothorax-segmentation/) competition.

# %% [markdown]
# **As internet is not allowed for this competition, I tried installing `segmentation_models.pytorch` by source using pip but due to some reasons it didn't work. So, as a [Jugaad](https://en.wikipedia.org/wiki/Jugaad) I took all of `segmentation_models.pytorch`'s UNet code and wrote it in a single file and added it as a dataset so as to use it for this kernel, its dependency [pretrained-models.pytorch](https://github.com/Cadene/pretrained-models.pytorch) is also added as a dataset.

# %%
# ! pip install git+https://github.com/qubvel/segmentation_models.pytorch --upgrade

# %%
encoder_name = 'se_resnext50_32x4d'
mask_size = 1600

# %%
# !pip install ../input/pretrainedmodels/pretrainedmodels-0.7.4/pretrainedmodels-0.7.4/ > /dev/null # no output
# package_path = './unetmodelscript/' # add unet script dataset
# import sys
# sys.path.append(package_path)
# from model import Unet # import Unet model from the script
import segmentation_models_pytorch as smp #import Unet, FPN, PSPNet

# %% [markdown]
# ## Imports

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='1'
import cv2
import pdb
import time
import warnings
import random
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook as tqdm
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader, Dataset, sampler
from matplotlib import pyplot as plt
from albumentations import (HorizontalFlip, ShiftScaleRotate, Normalize, Resize, Compose, GaussNoise)
from albumentations.torch import ToTensor
warnings.filterwarnings("ignore")
seed = 69
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True

from radam import RAdam

from torchsample.callbacks import EarlyStopping
from lovasz_loss import LovaszSoftmax

# %% [markdown]
# ## RLE-Mask utility functions

# %%
#https://www.kaggle.com/paulorzp/rle-functions-run-lenght-encode-decode
def mask2rle(img):
    '''
    img: numpy array, 1 -> mask, 0 -> background
    Returns run length as string formated
    '''
    pixels= img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def make_mask(row_id, df):
    '''Given a row index, return image_id and mask (256, 1600, 4) from the dataframe `df`'''
    fname = df.iloc[row_id].name
    labels = df.iloc[row_id][:4]
    masks = np.zeros((256, mask_size, 4), dtype=np.float32) # float32 is V.Imp
    # 4:class 1～4 (ch:0～3)

    for idx, label in enumerate(labels.values):
        if label is not np.nan:
            label = label.split(" ")
            positions = map(int, label[0::2])
            length = map(int, label[1::2])
            mask = np.zeros(256 * mask_size, dtype=np.uint8)
            for pos, le in zip(positions, length):
                mask[pos:(pos + le)] = 1
            masks[:, :, idx] = mask.reshape(256, mask_size, order='F')
    return fname, masks

# %% [markdown]
# ## Dataloader

# %%
class SteelDataset(Dataset):
    def __init__(self, df, data_folder, mean, std, phase):
        self.df = df
        self.root = data_folder
        self.mean = mean
        self.std = std
        self.phase = phase
        self.transforms = get_transforms(phase, mean, std)
        self.fnames = self.df.index.tolist()

    def __getitem__(self, idx):
        image_id, mask = make_mask(idx, self.df)
        image_path = os.path.join(self.root, "train_images",  image_id)
        img = cv2.imread(image_path)
        augmented = self.transforms(image=img, mask=mask)
        img = augmented['image']
        mask = augmented['mask'] # 1x256x1600x4
        mask = mask[0].permute(2, 0, 1) # 1x4x256x1600
        return img, mask

    def __len__(self):
        return len(self.fnames)


def get_transforms(phase, mean, std):
    list_transforms = []
    if phase == "train":
        list_transforms.extend(
            [
                HorizontalFlip(p=0.5), # only horizontal flip as of now
            ]
        )
    list_transforms.extend(
        [
            Resize(256, mask_size),
            Normalize(mean=mean, std=std, p=1),
            ToTensor(),
        ]
    )
    list_trfms = Compose(list_transforms)
    return list_trfms

def provider(
    data_folder,
    df_path,
    phase,
    mean=None,
    std=None,
    batch_size=8,
    num_workers=4,
):
    '''Returns dataloader for the model training'''
    df = pd.read_csv(df_path)
    # https://www.kaggle.com/amanooo/defect-detection-starter-u-net
    df['ImageId'], df['ClassId'] = zip(*df['ImageId_ClassId'].str.split('_'))
    df['ClassId'] = df['ClassId'].astype(int)
    df = df.pivot(index='ImageId',columns='ClassId',values='EncodedPixels')
    df['defects'] = df.count(axis=1)
    
    train_df, val_df = train_test_split(df, test_size=0.2, stratify=df["defects"], random_state=69)
    df = train_df if phase == "train" else val_df
    image_dataset = SteelDataset(df, data_folder, mean, std, phase)
    dataloader = DataLoader(
        image_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        pin_memory=True,
        shuffle=True,   
    )

    return dataloader

# %% [markdown]
# ## Some more utility functions
#
# Dice and IoU metric implementations, metric logger for training and validation.

# %%
def predict(X, threshold):
    '''X is sigmoid output of the model'''
    X_p = np.copy(X)
    preds = (X_p > threshold).astype('uint8')
    return preds

def metric(probability, truth, threshold=0.5, reduction='none'):
    '''Calculates dice of positive and negative images seperately'''
    '''probability and truth must be torch tensors'''
    batch_size = len(truth)
    with torch.no_grad():
        probability = probability.view(batch_size, -1)
        truth = truth.view(batch_size, -1)
        assert(probability.shape == truth.shape)

        p = (probability > threshold).float()
        t = (truth > 0.5).float()

        t_sum = t.sum(-1)
        p_sum = p.sum(-1)
        neg_index = torch.nonzero(t_sum == 0)
        pos_index = torch.nonzero(t_sum >= 1)

        dice_neg = (p_sum == 0).float()
        dice_pos = 2 * (p*t).sum(-1)/((p+t).sum(-1))

        dice_neg = dice_neg[neg_index]
        dice_pos = dice_pos[pos_index]
        dice = torch.cat([dice_pos, dice_neg])

        dice_neg = np.nan_to_num(dice_neg.mean().item(), 0)
        dice_pos = np.nan_to_num(dice_pos.mean().item(), 0)
        dice = dice.mean().item()

        num_neg = len(neg_index)
        num_pos = len(pos_index)

    return dice, dice_neg, dice_pos, num_neg, num_pos

class Meter:
    '''A meter to keep track of iou and dice scores throughout an epoch'''
    def __init__(self, phase, epoch):
        self.base_threshold = 0.5 # <<<<<<<<<<< here's the threshold
        self.base_dice_scores = []
        self.dice_neg_scores = []
        self.dice_pos_scores = []
        self.iou_scores = []

    def update(self, targets, outputs):
        probs = torch.sigmoid(outputs)
        dice, dice_neg, dice_pos, _, _ = metric(probs, targets, self.base_threshold)
        self.base_dice_scores.append(dice)
        self.dice_pos_scores.append(dice_pos)
        self.dice_neg_scores.append(dice_neg)
        preds = predict(probs, self.base_threshold)
        iou = compute_iou_batch(preds, targets, classes=[1])
        self.iou_scores.append(iou)

    def get_metrics(self):
        dice = np.mean(self.base_dice_scores)
        dice_neg = np.mean(self.dice_neg_scores)
        dice_pos = np.mean(self.dice_pos_scores)
        dices = [dice, dice_neg, dice_pos]
        iou = np.nanmean(self.iou_scores)
        return dices, iou

def epoch_log(phase, epoch, epoch_loss, meter, start):
    '''logging the metrics at the end of an epoch'''
    dices, iou = meter.get_metrics()
    dice, dice_neg, dice_pos = dices
    print("Loss: %0.4f | IoU: %0.4f | dice: %0.4f | dice_neg: %0.4f | dice_pos: %0.4f" % (epoch_loss, iou, dice, dice_neg, dice_pos))
    return dice, iou

def compute_ious(pred, label, classes, ignore_index=255, only_present=True):
    '''computes iou for one ground truth mask and predicted mask'''
    pred[label == ignore_index] = 0
    ious = []
    for c in classes:
        label_c = label == c
        if only_present and np.sum(label_c) == 0:
            ious.append(np.nan)
            continue
        pred_c = pred == c
        intersection = np.logical_and(pred_c, label_c).sum()
        union = np.logical_or(pred_c, label_c).sum()
        if union != 0:
            ious.append(intersection / union)
    return ious if ious else [1]

def compute_iou_batch(outputs, labels, classes=None):
    '''computes mean iou for a batch of ground truth masks and predicted masks'''
    ious = []
    preds = np.copy(outputs) # copy is imp
    labels = np.array(labels) # tensor to np
    for pred, label in zip(preds, labels):
        ious.append(np.nanmean(compute_ious(pred, label, classes)))
    iou = np.nanmean(ious)
    return iou

# %% [markdown]
# ## Loss

# %%
class BCESoftDiceLoss(nn.Module):
    def __init__(self, weight=None, size_average=True, w1=1, w2=1):
        super(BCESoftDiceLoss, self).__init__()
        self.bce_loss = nn.BCELoss(weight, size_average)
        self.w1 = w1
        self.w2 = w2
        
    def forward(self, logits, targets):
        # BCELoss2d
        probs        = torch.sigmoid(logits)
        probs_flat   = probs.view (-1)
        targets_flat = targets.view(-1)
        bce_loss = self.bce_loss(probs_flat, targets_flat)
        
        # SoftDiceLoss
        num = targets.size(0)
        probs = torch.sigmoid(logits)
        m1  = probs.view(num,-1)
        m2  = targets.view(num,-1)
        intersection = (m1 * m2)

        score = 2. * (intersection.sum(1)+1) / (m1.sum(1) + m2.sum(1)+1)
        soft_dice_loss = 1- score.sum()/num
        
        return self.w1 * bce_loss + self.w2 * soft_dice_loss

# %% [markdown]
# ## Model Initialization

# %%
# !mkdir -p /tmp/.cache/torch/checkpoints/
# !cp ../input/resnet18/resnet18.pth /tmp/.cache/torch/checkpoints/resnet18-5c106cde.pth

# %%
# model = Unet("resnet18", encoder_weights="imagenet", classes=4, activation=None)
model = smp.FPN(encoder_name, encoder_weights="imagenet", classes=4, activation=None)

# %%
# callbacks = [EarlyStopping(monitor='val_loss', patience=2)]
# model.set_callbacks(callbacks)

# %%
model # a *deeper* look
# Out:
# FPN(
#   (encoder): SENetEncoder(
#     (layer0): Sequential(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (pool): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     )
#     (layer1): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (layer2): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (3): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (layer3): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (3): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (4): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (5): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (layer4): Sequential(
#       (0): SEResNeXtBottleneck(
#         (conv1): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): SEResNeXtBottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#       (2): SEResNeXtBottleneck(
#         (conv1): Conv2d(2048, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn2): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se_module): SEModule(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#           (relu): ReLU(inplace=True)
#           (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (decoder): FPNDecoder(
#     (conv1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (p4): FPNBlock(
#       (skip_conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (p3): FPNBlock(
#       (skip_conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (p2): FPNBlock(
#       (skip_conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (s5): SegmentationBlock(
#       (block): Sequential(
#         (0): Conv3x3GNReLU(
#           (block): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): GroupNorm(32, 128, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (1): Conv3x3GNReLU(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): GroupNorm(32, 128, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (2): Conv3x3GNReLU(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): GroupNorm(32, 128, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (s4): SegmentationBlock(
#       (block): Sequential(
#         (0): Conv3x3GNReLU(
#           (block): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): GroupNorm(32, 128, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#         (1): Conv3x3GNReLU(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): GroupNorm(32, 128, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (s3): SegmentationBlock(
#       (block): Sequential(
#         (0): Conv3x3GNReLU(
#           (block): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): GroupNorm(32, 128, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (s2): SegmentationBlock(
#       (block): Sequential(
#         (0): Conv3x3GNReLU(
#           (block): Sequential(
#             (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): GroupNorm(32, 128, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (dropout): Dropout2d(p=0.2, inplace=True)
#     (final_conv): Conv2d(128, 4, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# ### Training and Validation

# %%
class Trainer(object):
    '''This class takes care of training and validation of our model'''
    def __init__(self, model):
        self.num_workers = 3
        self.batch_size = {"train": 7, "val": 7}
        self.accumulation_steps = 32 // self.batch_size['train']
        self.lr = 5e-4
        self.num_epochs = 1000
        self.best_loss = float("inf")
        self.phases = ["train", "val"]
        self.device = torch.device("cuda:0")
        torch.set_default_tensor_type("torch.cuda.FloatTensor")
        self.net = model
        self.criterion = torch.nn.BCEWithLogitsLoss()
        # self.criterion = LovaszSoftmax()
        # self.criterion = BCESoftDiceLoss(w1=1, w2=1)
        # self.optimizer = optim.Adam(self.net.parameters(), lr=self.lr)
        self.optimizer = RAdam(self.net.parameters(), lr=self.lr)
        self.scheduler = ReduceLROnPlateau(self.optimizer, mode="min", patience=3, verbose=True)
        self.net = self.net.to(self.device)
        cudnn.benchmark = True
        self.dataloaders = {
            phase: provider(
                data_folder=data_folder,
                df_path=train_df_path,
                phase=phase,
                mean=(0.485, 0.456, 0.406),
                std=(0.229, 0.224, 0.225),
                batch_size=self.batch_size[phase],
                num_workers=self.num_workers,
            )
            for phase in self.phases
        }
        self.losses = {phase: [] for phase in self.phases}
        self.iou_scores = {phase: [] for phase in self.phases}
        self.dice_scores = {phase: [] for phase in self.phases}
        
    def forward(self, images, targets):
        images = images.to(self.device)
        masks = targets.to(self.device)
        outputs = self.net(images)
        loss = self.criterion(outputs, masks)
        return loss, outputs

    def iterate(self, epoch, phase):
        meter = Meter(phase, epoch)
        start = time.strftime("%H:%M:%S")
        print(f"Starting epoch: {epoch} | phase: {phase} | ⏰: {start}")
        batch_size = self.batch_size[phase]
        self.net.train(phase == "train")
        dataloader = self.dataloaders[phase]
        running_loss = 0.0
        total_batches = len(dataloader)
#         tk0 = tqdm(dataloader, total=total_batches)
        self.optimizer.zero_grad()
        for itr, batch in enumerate(dataloader): # replace `dataloader` with `tk0` for tqdm
            images, targets = batch
            loss, outputs = self.forward(images, targets)
            loss = loss / self.accumulation_steps
            if phase == "train":
                loss.backward()
                if (itr + 1 ) % self.accumulation_steps == 0:
                    self.optimizer.step()
                    self.optimizer.zero_grad()
            running_loss += loss.item()
            outputs = outputs.detach().cpu()
            meter.update(targets, outputs)
#             tk0.set_postfix(loss=(running_loss / ((itr + 1))))
        epoch_loss = (running_loss * self.accumulation_steps) / total_batches
        dice, iou = epoch_log(phase, epoch, epoch_loss, meter, start)
        self.losses[phase].append(epoch_loss)
        self.dice_scores[phase].append(dice)
        self.iou_scores[phase].append(iou)
        torch.cuda.empty_cache()
        return epoch_loss

    def start(self):
        for epoch in range(self.num_epochs):
            self.iterate(epoch, "train")
            state = {
                "epoch": epoch,
                "best_loss": self.best_loss,
                "state_dict": self.net.state_dict(),
                "optimizer": self.optimizer.state_dict(),
            }
            with torch.no_grad():
                val_loss = self.iterate(epoch, "val")
                self.scheduler.step(val_loss)
            if val_loss < self.best_loss:
                print("******** New optimal found, saving state ********")
                state["best_loss"] = self.best_loss = val_loss
                torch.save(state, "./"+encoder_name+"_model.pth")
            if epoch % 10 == 0:
                torch.save(state, "./"+encoder_name+"_model_epoch_"+str(epoch)+".pth")
            print()

# %%
sample_submission_path = '../input/sample_submission.csv'
train_df_path = '../input/train.csv'
data_folder = "../input/"
test_data_folder = "../input/test_images"

# %%
model_trainer = Trainer(model)
model_trainer.start()
# Out:
# Starting epoch: 0 | phase: train | ⏰: 11:11:30
# Loss: 0.0567 | IoU: 0.2400 | dice: 0.3995 | dice_neg: 0.4842 | dice_pos: 0.3250
# Starting epoch: 0 | phase: val | ⏰: 11:26:00
# Loss: 0.0136 | IoU: 0.3184 | dice: 0.6578 | dice_neg: 0.9096 | dice_pos: 0.4189
# ******** New optimal found, saving state ********
#
# Starting epoch: 1 | phase: train | ⏰: 11:27:44
# Loss: 0.0145 | IoU: 0.3935 | dice: 0.6266 | dice_neg: 0.7689 | dice_pos: 0.5065
# Starting epoch: 1 | phase: val | ⏰: 11:42:25
# Loss: 0.0118 | IoU: 0.4519 | dice: 0.7028 | dice_neg: 0.8378 | dice_pos: 0.5740
# ******** New optimal found, saving state ********
#
# Starting epoch: 2 | phase: train | ⏰: 11:44:13
# Loss: 0.0119 | IoU: 0.4538 | dice: 0.6908 | dice_neg: 0.8272 | dice_pos: 0.5736
# Starting epoch: 2 | phase: val | ⏰: 11:58:53
# Loss: 0.0108 | IoU: 0.4833 | dice: 0.7543 | dice_neg: 0.8879 | dice_pos: 0.6107
# ******** New optimal found, saving state ********
#
# Starting epoch: 3 | phase: train | ⏰: 12:00:37
# Loss: 0.0105 | IoU: 0.4921 | dice: 0.7350 | dice_neg: 0.8680 | dice_pos: 0.6109
# Starting epoch: 3 | phase: val | ⏰: 12:15:21
# Loss: 0.0104 | IoU: 0.5314 | dice: 0.7590 | dice_neg: 0.8538 | dice_pos: 0.6603
# ******** New optimal found, saving state ********
#
# Starting epoch: 4 | phase: train | ⏰: 12:17:06
# Loss: 0.0107 | IoU: 0.4960 | dice: 0.7316 | dice_neg: 0.8581 | dice_pos: 0.6166
# Starting epoch: 4 | phase: val | ⏰: 12:31:52
# Loss: 0.0112 | IoU: 0.4811 | dice: 0.7534 | dice_neg: 0.9149 | dice_pos: 0.5986
#
# Starting epoch: 5 | phase: train | ⏰: 12:33:35
# Loss: 0.0097 | IoU: 0.5125 | dice: 0.7547 | dice_neg: 0.8872 | dice_pos: 0.6336
# Starting epoch: 5 | phase: val | ⏰: 12:48:14
# Loss: 0.0105 | IoU: 0.5001 | dice: 0.7778 | dice_neg: 0.9380 | dice_pos: 0.6254
#
# Starting epoch: 6 | phase: train | ⏰: 12:50:12
# Loss: 0.0096 | IoU: 0.5264 | dice: 0.7633 | dice_neg: 0.8906 | dice_pos: 0.6470
# Starting epoch: 6 | phase: val | ⏰: 13:05:01
# Loss: 0.0106 | IoU: 0.4684 | dice: 0.7592 | dice_neg: 0.9340 | dice_pos: 0.5903
#
# Starting epoch: 7 | phase: train | ⏰: 13:06:44
# Loss: 0.0098 | IoU: 0.5170 | dice: 0.7500 | dice_neg: 0.8745 | dice_pos: 0.6393
# Starting epoch: 7 | phase: val | ⏰: 13:21:26
# Loss: 0.0109 | IoU: 0.5054 | dice: 0.7797 | dice_neg: 0.9266 | dice_pos: 0.6280
# Epoch     7: reducing learning rate of group 0 to 5.0000e-05.
#
# Starting epoch: 8 | phase: train | ⏰: 13:23:12
# Loss: 0.0075 | IoU: 0.5846 | dice: 0.8166 | dice_neg: 0.9345 | dice_pos: 0.7019
# Starting epoch: 8 | phase: val | ⏰: 13:38:00
# Loss: 0.0090 | IoU: 0.5715 | dice: 0.8088 | dice_neg: 0.9188 | dice_pos: 0.6961
# ******** New optimal found, saving state ********
#
# Starting epoch: 9 | phase: train | ⏰: 13:39:43
# Loss: 0.0069 | IoU: 0.6024 | dice: 0.8310 | dice_neg: 0.9406 | dice_pos: 0.7194
# Starting epoch: 9 | phase: val | ⏰: 13:54:28
# Loss: 0.0093 | IoU: 0.5725 | dice: 0.8168 | dice_neg: 0.9282 | dice_pos: 0.6993
#
# Starting epoch: 10 | phase: train | ⏰: 13:56:13
# Loss: 0.0067 | IoU: 0.6132 | dice: 0.8359 | dice_neg: 0.9403 | dice_pos: 0.7276
# Starting epoch: 10 | phase: val | ⏰: 14:10:58
# Loss: 0.0094 | IoU: 0.5777 | dice: 0.8164 | dice_neg: 0.9245 | dice_pos: 0.7023
#
# Starting epoch: 11 | phase: train | ⏰: 14:12:41
# Loss: 0.0062 | IoU: 0.6284 | dice: 0.8437 | dice_neg: 0.9420 | dice_pos: 0.7429
# Starting epoch: 11 | phase: val | ⏰: 14:27:25
# Loss: 0.0092 | IoU: 0.5800 | dice: 0.8211 | dice_neg: 0.9219 | dice_pos: 0.6974
#
# Starting epoch: 12 | phase: train | ⏰: 14:29:07
# Loss: 0.0060 | IoU: 0.6383 | dice: 0.8489 | dice_neg: 0.9433 | dice_pos: 0.7519
# Starting epoch: 12 | phase: val | ⏰: 14:43:54
# Loss: 0.0091 | IoU: 0.5865 | dice: 0.8235 | dice_neg: 0.9357 | dice_pos: 0.7104
# Epoch    12: reducing learning rate of group 0 to 5.0000e-06.
#
# Starting epoch: 13 | phase: train | ⏰: 14:45:42
# Loss: 0.0055 | IoU: 0.6525 | dice: 0.8596 | dice_neg: 0.9516 | dice_pos: 0.7646
# Starting epoch: 13 | phase: val | ⏰: 15:00:26
# Loss: 0.0096 | IoU: 0.5874 | dice: 0.8229 | dice_neg: 0.9378 | dice_pos: 0.7109
#
# Starting epoch: 14 | phase: train | ⏰: 15:02:09
# Loss: 0.0054 | IoU: 0.6552 | dice: 0.8629 | dice_neg: 0.9579 | dice_pos: 0.7646
# Starting epoch: 14 | phase: val | ⏰: 15:16:57
# Loss: 0.0110 | IoU: 0.5780 | dice: 0.8156 | dice_neg: 0.9258 | dice_pos: 0.7045
#
# Starting epoch: 15 | phase: train | ⏰: 15:18:40
# Loss: 0.0054 | IoU: 0.6611 | dice: 0.8637 | dice_neg: 0.9556 | dice_pos: 0.7738
# Starting epoch: 15 | phase: val | ⏰: 15:33:26
# Loss: 0.0100 | IoU: 0.5810 | dice: 0.8247 | dice_neg: 0.9474 | dice_pos: 0.7033
#
# Starting epoch: 16 | phase: train | ⏰: 15:35:09
# Loss: 0.0053 | IoU: 0.6610 | dice: 0.8646 | dice_neg: 0.9597 | dice_pos: 0.7714
# Starting epoch: 16 | phase: val | ⏰: 15:49:54
# Loss: 0.0095 | IoU: 0.5894 | dice: 0.8257 | dice_neg: 0.9464 | dice_pos: 0.7096
# Epoch    16: reducing learning rate of group 0 to 5.0000e-07.
#
# Starting epoch: 17 | phase: train | ⏰: 15:51:37
# Loss: 0.0052 | IoU: 0.6614 | dice: 0.8655 | dice_neg: 0.9557 | dice_pos: 0.7731
# Starting epoch: 17 | phase: val | ⏰: 16:06:18
# Loss: 0.0097 | IoU: 0.5750 | dice: 0.8225 | dice_neg: 0.9510 | dice_pos: 0.6949
#
# Starting epoch: 18 | phase: train | ⏰: 16:08:00
# Loss: 0.0052 | IoU: 0.6645 | dice: 0.8647 | dice_neg: 0.9519 | dice_pos: 0.7737
# Starting epoch: 18 | phase: val | ⏰: 16:22:44
# Loss: 0.0098 | IoU: 0.5768 | dice: 0.8216 | dice_neg: 0.9440 | dice_pos: 0.7003
#
# Starting epoch: 19 | phase: train | ⏰: 16:24:27
# Loss: 0.0052 | IoU: 0.6661 | dice: 0.8662 | dice_neg: 0.9523 | dice_pos: 0.7730
# Starting epoch: 19 | phase: val | ⏰: 16:39:11
# Loss: 0.0097 | IoU: 0.5827 | dice: 0.8260 | dice_neg: 0.9419 | dice_pos: 0.7032
#
# Starting epoch: 20 | phase: train | ⏰: 16:40:54
# Loss: 0.0052 | IoU: 0.6659 | dice: 0.8671 | dice_neg: 0.9534 | dice_pos: 0.7773
# Starting epoch: 20 | phase: val | ⏰: 16:55:37
# Loss: 0.0101 | IoU: 0.5822 | dice: 0.8199 | dice_neg: 0.9439 | dice_pos: 0.6969
# Epoch    20: reducing learning rate of group 0 to 5.0000e-08.
#
# Starting epoch: 21 | phase: train | ⏰: 16:57:27
# Loss: 0.0052 | IoU: 0.6655 | dice: 0.8655 | dice_neg: 0.9559 | dice_pos: 0.7773
# Starting epoch: 21 | phase: val | ⏰: 17:12:07
# Loss: 0.0095 | IoU: 0.5981 | dice: 0.8263 | dice_neg: 0.9419 | dice_pos: 0.7135
#
# Starting epoch: 22 | phase: train | ⏰: 17:13:50
# Loss: 0.0052 | IoU: 0.6644 | dice: 0.8687 | dice_neg: 0.9533 | dice_pos: 0.7774
# Starting epoch: 22 | phase: val | ⏰: 17:28:24
# Loss: 0.0102 | IoU: 0.5685 | dice: 0.8150 | dice_neg: 0.9440 | dice_pos: 0.6895
#
# Starting epoch: 23 | phase: train | ⏰: 17:29:59
# Loss: 0.0052 | IoU: 0.6674 | dice: 0.8648 | dice_neg: 0.9499 | dice_pos: 0.7793
# Starting epoch: 23 | phase: val | ⏰: 17:44:21
# Loss: 0.0094 | IoU: 0.5907 | dice: 0.8288 | dice_neg: 0.9423 | dice_pos: 0.7113
#
# Starting epoch: 24 | phase: train | ⏰: 17:45:56
# Loss: 0.0052 | IoU: 0.6661 | dice: 0.8663 | dice_neg: 0.9554 | dice_pos: 0.7773
# Starting epoch: 24 | phase: val | ⏰: 18:00:17
# Loss: 0.0096 | IoU: 0.5862 | dice: 0.8204 | dice_neg: 0.9336 | dice_pos: 0.7046
# Epoch    24: reducing learning rate of group 0 to 5.0000e-09.
#
# Starting epoch: 25 | phase: train | ⏰: 18:01:56
# Loss: 0.0052 | IoU: 0.6666 | dice: 0.8669 | dice_neg: 0.9549 | dice_pos: 0.7781
# Starting epoch: 25 | phase: val | ⏰: 18:16:21
# Loss: 0.0095 | IoU: 0.5860 | dice: 0.8257 | dice_neg: 0.9501 | dice_pos: 0.7082
#
# Starting epoch: 26 | phase: train | ⏰: 18:17:57
# Loss: 0.0052 | IoU: 0.6636 | dice: 0.8639 | dice_neg: 0.9502 | dice_pos: 0.7721
# Starting epoch: 26 | phase: val | ⏰: 18:32:18
# Loss: 0.0102 | IoU: 0.5773 | dice: 0.8201 | dice_neg: 0.9462 | dice_pos: 0.6973
#
# Starting epoch: 27 | phase: train | ⏰: 18:33:54
# Loss: 0.0052 | IoU: 0.6662 | dice: 0.8649 | dice_neg: 0.9503 | dice_pos: 0.7758
# Starting epoch: 27 | phase: val | ⏰: 18:48:17
# Loss: 0.0106 | IoU: 0.5659 | dice: 0.8136 | dice_neg: 0.9315 | dice_pos: 0.6892
#
# Starting epoch: 28 | phase: train | ⏰: 18:49:53
# Loss: 0.0052 | IoU: 0.6632 | dice: 0.8652 | dice_neg: 0.9586 | dice_pos: 0.7753
# Starting epoch: 28 | phase: val | ⏰: 19:04:14
# Loss: 0.0093 | IoU: 0.5926 | dice: 0.8273 | dice_neg: 0.9485 | dice_pos: 0.7060
#
# Starting epoch: 29 | phase: train | ⏰: 19:05:49
# Loss: 0.0052 | IoU: 0.6674 | dice: 0.8668 | dice_neg: 0.9521 | dice_pos: 0.7753
# Starting epoch: 29 | phase: val | ⏰: 19:20:12
# Loss: 0.0098 | IoU: 0.5846 | dice: 0.8210 | dice_neg: 0.9309 | dice_pos: 0.7076
#
# Starting epoch: 30 | phase: train | ⏰: 19:21:47
# Loss: 0.0052 | IoU: 0.6664 | dice: 0.8669 | dice_neg: 0.9555 | dice_pos: 0.7782
# Starting epoch: 30 | phase: val | ⏰: 19:36:08
# Loss: 0.0100 | IoU: 0.5853 | dice: 0.8257 | dice_neg: 0.9413 | dice_pos: 0.7057
#
# Starting epoch: 31 | phase: train | ⏰: 19:37:43
# Loss: 0.0052 | IoU: 0.6614 | dice: 0.8655 | dice_neg: 0.9555 | dice_pos: 0.7718
# Starting epoch: 31 | phase: val | ⏰: 19:52:05
# Loss: 0.0094 | IoU: 0.5908 | dice: 0.8269 | dice_neg: 0.9371 | dice_pos: 0.7104
#
# Starting epoch: 32 | phase: train | ⏰: 19:53:41
# Loss: 0.0052 | IoU: 0.6639 | dice: 0.8665 | dice_neg: 0.9540 | dice_pos: 0.7752
# Starting epoch: 32 | phase: val | ⏰: 20:08:04
# Loss: 0.0143 | IoU: 0.5434 | dice: 0.7925 | dice_neg: 0.9423 | dice_pos: 0.6521
#
# Starting epoch: 33 | phase: train | ⏰: 20:09:39
# Loss: 0.0052 | IoU: 0.6656 | dice: 0.8673 | dice_neg: 0.9495 | dice_pos: 0.7735
# Starting epoch: 33 | phase: val | ⏰: 20:24:00
# Loss: 0.0098 | IoU: 0.5866 | dice: 0.8268 | dice_neg: 0.9381 | dice_pos: 0.7109
#
# Starting epoch: 34 | phase: train | ⏰: 20:25:34
# Loss: 0.0052 | IoU: 0.6643 | dice: 0.8655 | dice_neg: 0.9556 | dice_pos: 0.7768
# Starting epoch: 34 | phase: val | ⏰: 20:39:55
# Loss: 0.0101 | IoU: 0.5842 | dice: 0.8238 | dice_neg: 0.9408 | dice_pos: 0.7045
#
# Starting epoch: 35 | phase: train | ⏰: 20:41:29
# Loss: 0.0052 | IoU: 0.6647 | dice: 0.8659 | dice_neg: 0.9575 | dice_pos: 0.7761
# Starting epoch: 35 | phase: val | ⏰: 20:55:54
# Loss: 0.0096 | IoU: 0.5827 | dice: 0.8238 | dice_neg: 0.9358 | dice_pos: 0.7015
#
# Starting epoch: 36 | phase: train | ⏰: 20:57:33
# Loss: 0.0052 | IoU: 0.6653 | dice: 0.8645 | dice_neg: 0.9575 | dice_pos: 0.7778
# Starting epoch: 36 | phase: val | ⏰: 21:11:57
# Loss: 0.0094 | IoU: 0.5920 | dice: 0.8255 | dice_neg: 0.9341 | dice_pos: 0.7069
#
# Starting epoch: 37 | phase: train | ⏰: 21:13:32
# Loss: 0.0052 | IoU: 0.6640 | dice: 0.8662 | dice_neg: 0.9493 | dice_pos: 0.7756
# Starting epoch: 37 | phase: val | ⏰: 21:27:52
# Loss: 0.0103 | IoU: 0.5765 | dice: 0.8219 | dice_neg: 0.9370 | dice_pos: 0.7022
#
# Starting epoch: 38 | phase: train | ⏰: 21:29:27
# Loss: 0.0052 | IoU: 0.6661 | dice: 0.8665 | dice_neg: 0.9532 | dice_pos: 0.7789
# Starting epoch: 38 | phase: val | ⏰: 21:43:45
# Loss: 0.0099 | IoU: 0.5847 | dice: 0.8256 | dice_neg: 0.9353 | dice_pos: 0.7083
#
# Starting epoch: 39 | phase: train | ⏰: 21:45:20
# Loss: 0.0052 | IoU: 0.6671 | dice: 0.8667 | dice_neg: 0.9567 | dice_pos: 0.7765
# Starting epoch: 39 | phase: val | ⏰: 21:59:40
# Loss: 0.0097 | IoU: 0.5889 | dice: 0.8262 | dice_neg: 0.9504 | dice_pos: 0.7108
#
# Starting epoch: 40 | phase: train | ⏰: 22:01:14
# Loss: 0.0052 | IoU: 0.6662 | dice: 0.8653 | dice_neg: 0.9562 | dice_pos: 0.7728
# Starting epoch: 40 | phase: val | ⏰: 22:15:35
# Loss: 0.0100 | IoU: 0.5850 | dice: 0.8249 | dice_neg: 0.9428 | dice_pos: 0.7024
#
# Starting epoch: 41 | phase: train | ⏰: 22:17:09
# Loss: 0.0052 | IoU: 0.6645 | dice: 0.8672 | dice_neg: 0.9619 | dice_pos: 0.7757
# Starting epoch: 41 | phase: val | ⏰: 22:31:27
# Loss: 0.0096 | IoU: 0.5887 | dice: 0.8248 | dice_neg: 0.9397 | dice_pos: 0.7030
#
# Starting epoch: 42 | phase: train | ⏰: 22:33:01
# Loss: 0.0052 | IoU: 0.6643 | dice: 0.8666 | dice_neg: 0.9527 | dice_pos: 0.7736
# Starting epoch: 42 | phase: val | ⏰: 22:47:19
# Loss: 0.0093 | IoU: 0.5891 | dice: 0.8228 | dice_neg: 0.9440 | dice_pos: 0.7030
#
# Starting epoch: 43 | phase: train | ⏰: 22:48:53
# Loss: 0.0052 | IoU: 0.6653 | dice: 0.8655 | dice_neg: 0.9449 | dice_pos: 0.7742
# Starting epoch: 43 | phase: val | ⏰: 23:03:10
# Loss: 0.0100 | IoU: 0.5859 | dice: 0.8228 | dice_neg: 0.9319 | dice_pos: 0.7072
#
# Starting epoch: 44 | phase: train | ⏰: 23:04:46
# Loss: 0.0052 | IoU: 0.6644 | dice: 0.8648 | dice_neg: 0.9557 | dice_pos: 0.7756
# Starting epoch: 44 | phase: val | ⏰: 23:19:08
# Loss: 0.0109 | IoU: 0.5597 | dice: 0.8126 | dice_neg: 0.9437 | dice_pos: 0.6846
#
# Starting epoch: 45 | phase: train | ⏰: 23:20:44
# Loss: 0.0052 | IoU: 0.6634 | dice: 0.8660 | dice_neg: 0.9549 | dice_pos: 0.7730
# Starting epoch: 45 | phase: val | ⏰: 23:35:03
# Loss: 0.0106 | IoU: 0.5667 | dice: 0.8138 | dice_neg: 0.9484 | dice_pos: 0.6863
#
# Starting epoch: 46 | phase: train | ⏰: 23:36:38
# Loss: 0.0052 | IoU: 0.6634 | dice: 0.8653 | dice_neg: 0.9547 | dice_pos: 0.7745
# Starting epoch: 46 | phase: val | ⏰: 23:51:00
# Loss: 0.0099 | IoU: 0.5838 | dice: 0.8271 | dice_neg: 0.9435 | dice_pos: 0.7046
#
# Starting epoch: 47 | phase: train | ⏰: 23:52:38
# Loss: 0.0052 | IoU: 0.6643 | dice: 0.8660 | dice_neg: 0.9516 | dice_pos: 0.7747
# Starting epoch: 47 | phase: val | ⏰: 00:06:58
# Loss: 0.0094 | IoU: 0.5894 | dice: 0.8270 | dice_neg: 0.9421 | dice_pos: 0.7105
#
# Starting epoch: 48 | phase: train | ⏰: 00:08:33
# Loss: 0.0052 | IoU: 0.6648 | dice: 0.8650 | dice_neg: 0.9523 | dice_pos: 0.7750
# Starting epoch: 48 | phase: val | ⏰: 00:22:57
# Loss: 0.0112 | IoU: 0.5557 | dice: 0.8037 | dice_neg: 0.9280 | dice_pos: 0.6770
#
# Starting epoch: 49 | phase: train | ⏰: 00:24:36
# Loss: 0.0052 | IoU: 0.6667 | dice: 0.8664 | dice_neg: 0.9542 | dice_pos: 0.7766
# Starting epoch: 49 | phase: val | ⏰: 00:39:04
# Loss: 0.0095 | IoU: 0.5846 | dice: 0.8247 | dice_neg: 0.9346 | dice_pos: 0.7078
#
# Starting epoch: 50 | phase: train | ⏰: 00:40:42
# Loss: 0.0052 | IoU: 0.6642 | dice: 0.8657 | dice_neg: 0.9465 | dice_pos: 0.7736
# Starting epoch: 50 | phase: val | ⏰: 00:55:05
# Loss: 0.0099 | IoU: 0.5799 | dice: 0.8240 | dice_neg: 0.9539 | dice_pos: 0.6989
#
# Starting epoch: 51 | phase: train | ⏰: 00:56:44
# Loss: 0.0052 | IoU: 0.6625 | dice: 0.8646 | dice_neg: 0.9499 | dice_pos: 0.7712
# Starting epoch: 51 | phase: val | ⏰: 01:11:09
# Loss: 0.0095 | IoU: 0.5906 | dice: 0.8269 | dice_neg: 0.9472 | dice_pos: 0.7106
#
# Starting epoch: 52 | phase: train | ⏰: 01:12:45
# Loss: 0.0052 | IoU: 0.6662 | dice: 0.8666 | dice_neg: 0.9562 | dice_pos: 0.7769
# Starting epoch: 52 | phase: val | ⏰: 01:27:06
# Loss: 0.0096 | IoU: 0.5902 | dice: 0.8253 | dice_neg: 0.9386 | dice_pos: 0.7025
#
# Starting epoch: 53 | phase: train | ⏰: 01:28:44
# Loss: 0.0052 | IoU: 0.6662 | dice: 0.8667 | dice_neg: 0.9549 | dice_pos: 0.7768
# Starting epoch: 53 | phase: val | ⏰: 01:43:06
# Loss: 0.0099 | IoU: 0.5778 | dice: 0.8211 | dice_neg: 0.9509 | dice_pos: 0.7008
#
# Starting epoch: 54 | phase: train | ⏰: 01:44:41
# Loss: 0.0052 | IoU: 0.6642 | dice: 0.8646 | dice_neg: 0.9525 | dice_pos: 0.7755
# Starting epoch: 54 | phase: val | ⏰: 01:59:04
# Loss: 0.0095 | IoU: 0.5875 | dice: 0.8276 | dice_neg: 0.9497 | dice_pos: 0.7080
#
# Starting epoch: 55 | phase: train | ⏰: 02:00:42
# Loss: 0.0052 | IoU: 0.6657 | dice: 0.8667 | dice_neg: 0.9560 | dice_pos: 0.7753
# Starting epoch: 55 | phase: val | ⏰: 02:15:05
# Loss: 0.0114 | IoU: 0.5542 | dice: 0.8096 | dice_neg: 0.9476 | dice_pos: 0.6733
#
# Starting epoch: 56 | phase: train | ⏰: 02:16:40
# Loss: 0.0052 | IoU: 0.6650 | dice: 0.8651 | dice_neg: 0.9524 | dice_pos: 0.7782
# Starting epoch: 56 | phase: val | ⏰: 02:30:58
# Loss: 0.0101 | IoU: 0.5782 | dice: 0.8219 | dice_neg: 0.9317 | dice_pos: 0.7000
#
# Starting epoch: 57 | phase: train | ⏰: 02:32:32
# Loss: 0.0052 | IoU: 0.6657 | dice: 0.8664 | dice_neg: 0.9567 | dice_pos: 0.7746
# Starting epoch: 57 | phase: val | ⏰: 02:46:52
# Loss: 0.0138 | IoU: 0.5408 | dice: 0.7945 | dice_neg: 0.9406 | dice_pos: 0.6558
#
# Starting epoch: 58 | phase: train | ⏰: 02:48:27
# Loss: 0.0052 | IoU: 0.6646 | dice: 0.8664 | dice_neg: 0.9529 | dice_pos: 0.7760
# Starting epoch: 58 | phase: val | ⏰: 03:02:46
# Loss: 0.0094 | IoU: 0.5874 | dice: 0.8284 | dice_neg: 0.9417 | dice_pos: 0.7032
#
# Starting epoch: 59 | phase: train | ⏰: 03:04:20
# Loss: 0.0052 | IoU: 0.6654 | dice: 0.8653 | dice_neg: 0.9532 | dice_pos: 0.7760
# Starting epoch: 59 | phase: val | ⏰: 03:18:39
# Loss: 0.0096 | IoU: 0.5880 | dice: 0.8270 | dice_neg: 0.9400 | dice_pos: 0.7067
#
# Starting epoch: 60 | phase: train | ⏰: 03:20:13
# Loss: 0.0052 | IoU: 0.6652 | dice: 0.8644 | dice_neg: 0.9557 | dice_pos: 0.7789
# Starting epoch: 60 | phase: val | ⏰: 03:34:33
# Loss: 0.0101 | IoU: 0.5729 | dice: 0.8195 | dice_neg: 0.9504 | dice_pos: 0.6935
#
# Starting epoch: 61 | phase: train | ⏰: 03:36:07
# Loss: 0.0052 | IoU: 0.6645 | dice: 0.8666 | dice_neg: 0.9612 | dice_pos: 0.7753
# Starting epoch: 61 | phase: val | ⏰: 03:50:26
# Loss: 0.0095 | IoU: 0.5888 | dice: 0.8266 | dice_neg: 0.9256 | dice_pos: 0.7100
#
# Starting epoch: 62 | phase: train | ⏰: 03:52:00
# Loss: 0.0052 | IoU: 0.6655 | dice: 0.8669 | dice_neg: 0.9547 | dice_pos: 0.7780
# Starting epoch: 62 | phase: val | ⏰: 04:06:25
# Loss: 0.0095 | IoU: 0.5906 | dice: 0.8245 | dice_neg: 0.9249 | dice_pos: 0.7096
#
# Starting epoch: 63 | phase: train | ⏰: 04:07:59
# Loss: 0.0052 | IoU: 0.6620 | dice: 0.8655 | dice_neg: 0.9503 | dice_pos: 0.7735
# Starting epoch: 63 | phase: val | ⏰: 04:22:18
# Loss: 0.0102 | IoU: 0.5810 | dice: 0.8216 | dice_neg: 0.9399 | dice_pos: 0.7062
#
# Starting epoch: 64 | phase: train | ⏰: 04:23:53
# Loss: 0.0052 | IoU: 0.6649 | dice: 0.8677 | dice_neg: 0.9584 | dice_pos: 0.7767
# Starting epoch: 64 | phase: val | ⏰: 04:38:13
# Loss: 0.0098 | IoU: 0.5881 | dice: 0.8261 | dice_neg: 0.9435 | dice_pos: 0.7066
#
# Starting epoch: 65 | phase: train | ⏰: 04:39:49
# Loss: 0.0052 | IoU: 0.6630 | dice: 0.8648 | dice_neg: 0.9526 | dice_pos: 0.7746
# Starting epoch: 65 | phase: val | ⏰: 04:54:09
# Loss: 0.0096 | IoU: 0.5933 | dice: 0.8222 | dice_neg: 0.9317 | dice_pos: 0.7098
#
# Starting epoch: 66 | phase: train | ⏰: 04:55:44
# Loss: 0.0052 | IoU: 0.6623 | dice: 0.8663 | dice_neg: 0.9597 | dice_pos: 0.7745
# Starting epoch: 66 | phase: val | ⏰: 05:10:05
# Loss: 0.0101 | IoU: 0.5851 | dice: 0.8215 | dice_neg: 0.9333 | dice_pos: 0.7060
#
# Starting epoch: 67 | phase: train | ⏰: 05:11:40
# Loss: 0.0052 | IoU: 0.6638 | dice: 0.8653 | dice_neg: 0.9548 | dice_pos: 0.7713
# Starting epoch: 67 | phase: val | ⏰: 05:26:02
# Loss: 0.0101 | IoU: 0.5836 | dice: 0.8229 | dice_neg: 0.9463 | dice_pos: 0.7062
#
# Starting epoch: 68 | phase: train | ⏰: 05:27:37
# Loss: 0.0052 | IoU: 0.6662 | dice: 0.8655 | dice_neg: 0.9558 | dice_pos: 0.7750
# Starting epoch: 68 | phase: val | ⏰: 05:42:02
# Loss: 0.0098 | IoU: 0.5886 | dice: 0.8260 | dice_neg: 0.9419 | dice_pos: 0.7120
#
# Starting epoch: 69 | phase: train | ⏰: 05:43:37
# Loss: 0.0052 | IoU: 0.6655 | dice: 0.8654 | dice_neg: 0.9534 | dice_pos: 0.7764
# Starting epoch: 69 | phase: val | ⏰: 05:57:57
# Loss: 0.0130 | IoU: 0.5334 | dice: 0.7938 | dice_neg: 0.9326 | dice_pos: 0.6475
#
# Starting epoch: 70 | phase: train | ⏰: 05:59:32
# Loss: 0.0052 | IoU: 0.6643 | dice: 0.8634 | dice_neg: 0.9538 | dice_pos: 0.7751
# Starting epoch: 70 | phase: val | ⏰: 06:13:52
# Loss: 0.0098 | IoU: 0.5791 | dice: 0.8195 | dice_neg: 0.9325 | dice_pos: 0.7024
#
# Starting epoch: 71 | phase: train | ⏰: 06:15:31
# Loss: 0.0052 | IoU: 0.6638 | dice: 0.8653 | dice_neg: 0.9483 | dice_pos: 0.7756
# Starting epoch: 71 | phase: val | ⏰: 06:29:54
# Loss: 0.0096 | IoU: 0.5894 | dice: 0.8256 | dice_neg: 0.9475 | dice_pos: 0.7109
#
# Starting epoch: 72 | phase: train | ⏰: 06:31:30
# Loss: 0.0052 | IoU: 0.6657 | dice: 0.8656 | dice_neg: 0.9536 | dice_pos: 0.7784
# Starting epoch: 72 | phase: val | ⏰: 06:45:48
# Loss: 0.0097 | IoU: 0.5898 | dice: 0.8248 | dice_neg: 0.9371 | dice_pos: 0.7118
#
# Starting epoch: 73 | phase: train | ⏰: 06:47:23
# Loss: 0.0052 | IoU: 0.6646 | dice: 0.8640 | dice_neg: 0.9499 | dice_pos: 0.7764
# Starting epoch: 73 | phase: val | ⏰: 07:01:47
# Loss: 0.0094 | IoU: 0.5893 | dice: 0.8260 | dice_neg: 0.9486 | dice_pos: 0.7096
#
# Starting epoch: 74 | phase: train | ⏰: 07:03:23
# Loss: 0.0052 | IoU: 0.6649 | dice: 0.8664 | dice_neg: 0.9533 | dice_pos: 0.7776
# Starting epoch: 74 | phase: val | ⏰: 07:17:48
# Loss: 0.0097 | IoU: 0.5859 | dice: 0.8223 | dice_neg: 0.9413 | dice_pos: 0.7057
#
# Starting epoch: 75 | phase: train | ⏰: 07:19:29
# Loss: 0.0052 | IoU: 0.6654 | dice: 0.8666 | dice_neg: 0.9557 | dice_pos: 0.7767
# Starting epoch: 75 | phase: val | ⏰: 07:33:51
# Loss: 0.0129 | IoU: 0.5383 | dice: 0.7956 | dice_neg: 0.9423 | dice_pos: 0.6547
#
# Starting epoch: 76 | phase: train | ⏰: 07:35:25
# Loss: 0.0052 | IoU: 0.6631 | dice: 0.8660 | dice_neg: 0.9554 | dice_pos: 0.7715
# Starting epoch: 76 | phase: val | ⏰: 07:49:44
# Loss: 0.0095 | IoU: 0.5879 | dice: 0.8278 | dice_neg: 0.9478 | dice_pos: 0.7101
#
# Starting epoch: 77 | phase: train | ⏰: 07:51:19
# Loss: 0.0052 | IoU: 0.6657 | dice: 0.8658 | dice_neg: 0.9534 | dice_pos: 0.7768
# Starting epoch: 77 | phase: val | ⏰: 08:05:38
# Loss: 0.0103 | IoU: 0.5771 | dice: 0.8214 | dice_neg: 0.9467 | dice_pos: 0.6954
#
# Starting epoch: 78 | phase: train | ⏰: 08:07:13
# Loss: 0.0052 | IoU: 0.6627 | dice: 0.8656 | dice_neg: 0.9585 | dice_pos: 0.7734
# Starting epoch: 78 | phase: val | ⏰: 08:21:40
# Loss: 0.0099 | IoU: 0.5795 | dice: 0.8208 | dice_neg: 0.9406 | dice_pos: 0.7028
#
# Starting epoch: 79 | phase: train | ⏰: 08:23:19
# Loss: 0.0052 | IoU: 0.6647 | dice: 0.8651 | dice_neg: 0.9536 | dice_pos: 0.7744
# Starting epoch: 79 | phase: val | ⏰: 08:37:37
# Loss: 0.0103 | IoU: 0.5723 | dice: 0.8171 | dice_neg: 0.9417 | dice_pos: 0.6945
#
# Starting epoch: 80 | phase: train | ⏰: 08:39:12
# Loss: 0.0052 | IoU: 0.6639 | dice: 0.8653 | dice_neg: 0.9557 | dice_pos: 0.7759
# Starting epoch: 80 | phase: val | ⏰: 08:53:31
# Loss: 0.0118 | IoU: 0.5396 | dice: 0.8006 | dice_neg: 0.9482 | dice_pos: 0.6551
#
# Starting epoch: 81 | phase: train | ⏰: 08:55:10
# Loss: 0.0052 | IoU: 0.6663 | dice: 0.8655 | dice_neg: 0.9567 | dice_pos: 0.7791
# Starting epoch: 81 | phase: val | ⏰: 09:09:34
# Loss: 0.0096 | IoU: 0.5903 | dice: 0.8267 | dice_neg: 0.9419 | dice_pos: 0.7085
#
# Starting epoch: 82 | phase: train | ⏰: 09:11:09
# Loss: 0.0052 | IoU: 0.6652 | dice: 0.8656 | dice_neg: 0.9556 | dice_pos: 0.7776
# Starting epoch: 82 | phase: val | ⏰: 09:25:31
# Loss: 0.0098 | IoU: 0.5870 | dice: 0.8242 | dice_neg: 0.9284 | dice_pos: 0.7090
#
# Starting epoch: 83 | phase: train | ⏰: 09:27:10
# Loss: 0.0052 | IoU: 0.6641 | dice: 0.8652 | dice_neg: 0.9496 | dice_pos: 0.7771
# Starting epoch: 83 | phase: val | ⏰: 09:41:33
# Loss: 0.0096 | IoU: 0.5881 | dice: 0.8270 | dice_neg: 0.9430 | dice_pos: 0.7079
#
# Starting epoch: 84 | phase: train | ⏰: 09:43:07
# Loss: 0.0052 | IoU: 0.6665 | dice: 0.8684 | dice_neg: 0.9588 | dice_pos: 0.7781
# Starting epoch: 84 | phase: val | ⏰: 09:57:25
# Loss: 0.0095 | IoU: 0.5871 | dice: 0.8259 | dice_neg: 0.9508 | dice_pos: 0.7088
#
# Starting epoch: 85 | phase: train | ⏰: 09:59:00
# Loss: 0.0052 | IoU: 0.6660 | dice: 0.8656 | dice_neg: 0.9522 | dice_pos: 0.7760
# Starting epoch: 85 | phase: val | ⏰: 10:13:20
# Loss: 0.0099 | IoU: 0.5729 | dice: 0.8215 | dice_neg: 0.9381 | dice_pos: 0.6945
#
# Starting epoch: 86 | phase: train | ⏰: 10:14:57
# Loss: 0.0052 | IoU: 0.6692 | dice: 0.8667 | dice_neg: 0.9562 | dice_pos: 0.7787
# Starting epoch: 86 | phase: val | ⏰: 10:29:21
# Loss: 0.0105 | IoU: 0.5645 | dice: 0.8125 | dice_neg: 0.9432 | dice_pos: 0.6861
#
# Starting epoch: 87 | phase: train | ⏰: 10:30:56
# Loss: 0.0052 | IoU: 0.6671 | dice: 0.8673 | dice_neg: 0.9563 | dice_pos: 0.7775
# Starting epoch: 87 | phase: val | ⏰: 10:45:17
# Loss: 0.0103 | IoU: 0.5708 | dice: 0.8192 | dice_neg: 0.9464 | dice_pos: 0.6951
#
# Starting epoch: 88 | phase: train | ⏰: 10:46:53
# Loss: 0.0052 | IoU: 0.6671 | dice: 0.8687 | dice_neg: 0.9597 | dice_pos: 0.7785
# Starting epoch: 88 | phase: val | ⏰: 11:01:13
# Loss: 0.0095 | IoU: 0.5841 | dice: 0.8249 | dice_neg: 0.9354 | dice_pos: 0.7060
#
# Starting epoch: 89 | phase: train | ⏰: 11:02:48
# Loss: 0.0052 | IoU: 0.6647 | dice: 0.8653 | dice_neg: 0.9504 | dice_pos: 0.7757
# Starting epoch: 89 | phase: val | ⏰: 11:17:09
# Loss: 0.0104 | IoU: 0.5758 | dice: 0.8196 | dice_neg: 0.9335 | dice_pos: 0.6983
#
# Starting epoch: 90 | phase: train | ⏰: 11:18:43
# Loss: 0.0052 | IoU: 0.6633 | dice: 0.8646 | dice_neg: 0.9487 | dice_pos: 0.7736
# Starting epoch: 90 | phase: val | ⏰: 11:33:03
# Loss: 0.0111 | IoU: 0.5532 | dice: 0.8083 | dice_neg: 0.9486 | dice_pos: 0.6708
#
# Starting epoch: 91 | phase: train | ⏰: 11:34:41
# Loss: 0.0052 | IoU: 0.6643 | dice: 0.8655 | dice_neg: 0.9559 | dice_pos: 0.7754
# Starting epoch: 91 | phase: val | ⏰: 11:49:05
# Loss: 0.0101 | IoU: 0.5807 | dice: 0.8244 | dice_neg: 0.9416 | dice_pos: 0.6942
#
# Starting epoch: 92 | phase: train | ⏰: 11:50:40
# Loss: 0.0052 | IoU: 0.6666 | dice: 0.8655 | dice_neg: 0.9509 | dice_pos: 0.7786
# Starting epoch: 92 | phase: val | ⏰: 12:05:03
# Loss: 0.0096 | IoU: 0.5897 | dice: 0.8234 | dice_neg: 0.9279 | dice_pos: 0.7050
#
# Starting epoch: 93 | phase: train | ⏰: 12:06:37
# Loss: 0.0052 | IoU: 0.6638 | dice: 0.8667 | dice_neg: 0.9595 | dice_pos: 0.7734
# Starting epoch: 93 | phase: val | ⏰: 12:20:55
# Loss: 0.0095 | IoU: 0.5899 | dice: 0.8255 | dice_neg: 0.9238 | dice_pos: 0.7104
#
# Starting epoch: 94 | phase: train | ⏰: 12:22:29
# Loss: 0.0052 | IoU: 0.6644 | dice: 0.8663 | dice_neg: 0.9558 | dice_pos: 0.7756
# Starting epoch: 94 | phase: val | ⏰: 12:36:48
# Loss: 0.0096 | IoU: 0.5917 | dice: 0.8267 | dice_neg: 0.9461 | dice_pos: 0.7154
#
# Starting epoch: 95 | phase: train | ⏰: 12:38:23
# Loss: 0.0052 | IoU: 0.6646 | dice: 0.8665 | dice_neg: 0.9566 | dice_pos: 0.7730
# Starting epoch: 95 | phase: val | ⏰: 12:52:43
# Loss: 0.0100 | IoU: 0.5781 | dice: 0.8198 | dice_neg: 0.9359 | dice_pos: 0.7014
#
# Starting epoch: 96 | phase: train | ⏰: 12:54:22
# Loss: 0.0052 | IoU: 0.6629 | dice: 0.8654 | dice_neg: 0.9582 | dice_pos: 0.7742
# Starting epoch: 96 | phase: val | ⏰: 13:08:50
# Loss: 0.0094 | IoU: 0.5920 | dice: 0.8250 | dice_neg: 0.9413 | dice_pos: 0.7061
#
# Starting epoch: 97 | phase: train | ⏰: 13:10:28
# Loss: 0.0052 | IoU: 0.6655 | dice: 0.8651 | dice_neg: 0.9482 | dice_pos: 0.7776
# Starting epoch: 97 | phase: val | ⏰: 13:24:49
# Loss: 0.0113 | IoU: 0.5703 | dice: 0.8144 | dice_neg: 0.9502 | dice_pos: 0.6933
#
# Starting epoch: 98 | phase: train | ⏰: 13:26:23
# Loss: 0.0052 | IoU: 0.6673 | dice: 0.8655 | dice_neg: 0.9479 | dice_pos: 0.7762
# Starting epoch: 98 | phase: val | ⏰: 13:40:42
# Loss: 0.0095 | IoU: 0.5908 | dice: 0.8277 | dice_neg: 0.9441 | dice_pos: 0.7112
#
# Starting epoch: 99 | phase: train | ⏰: 13:42:17
# Loss: 0.0052 | IoU: 0.6664 | dice: 0.8662 | dice_neg: 0.9582 | dice_pos: 0.7798
# Starting epoch: 99 | phase: val | ⏰: 13:56:39
# Loss: 0.0097 | IoU: 0.5876 | dice: 0.8238 | dice_neg: 0.9342 | dice_pos: 0.7083
#
# Starting epoch: 100 | phase: train | ⏰: 13:58:17
# Loss: 0.0052 | IoU: 0.6635 | dice: 0.8661 | dice_neg: 0.9549 | dice_pos: 0.7722
# Starting epoch: 100 | phase: val | ⏰: 14:12:38
# Loss: 0.0095 | IoU: 0.5837 | dice: 0.8244 | dice_neg: 0.9404 | dice_pos: 0.7061
#
# Starting epoch: 101 | phase: train | ⏰: 14:14:16
# Loss: 0.0052 | IoU: 0.6667 | dice: 0.8661 | dice_neg: 0.9518 | dice_pos: 0.7790
# Starting epoch: 101 | phase: val | ⏰: 14:28:40
# Loss: 0.0098 | IoU: 0.5820 | dice: 0.8263 | dice_neg: 0.9458 | dice_pos: 0.7069
#
# Starting epoch: 102 | phase: train | ⏰: 14:30:15
# Loss: 0.0052 | IoU: 0.6678 | dice: 0.8672 | dice_neg: 0.9536 | dice_pos: 0.7804
# Starting epoch: 102 | phase: val | ⏰: 14:44:35
# Loss: 0.0099 | IoU: 0.5835 | dice: 0.8237 | dice_neg: 0.9436 | dice_pos: 0.6971
#
# Starting epoch: 103 | phase: train | ⏰: 14:46:09
# Loss: 0.0052 | IoU: 0.6642 | dice: 0.8660 | dice_neg: 0.9552 | dice_pos: 0.7754
# Starting epoch: 103 | phase: val | ⏰: 15:00:29
# Loss: 0.0099 | IoU: 0.5878 | dice: 0.8265 | dice_neg: 0.9426 | dice_pos: 0.7086
#
# Starting epoch: 104 | phase: train | ⏰: 15:02:04
# Loss: 0.0052 | IoU: 0.6648 | dice: 0.8664 | dice_neg: 0.9531 | dice_pos: 0.7769
# Starting epoch: 104 | phase: val | ⏰: 15:16:23
# Loss: 0.0124 | IoU: 0.5349 | dice: 0.7927 | dice_neg: 0.9434 | dice_pos: 0.6473
#
# Starting epoch: 105 | phase: train | ⏰: 15:17:57
# Loss: 0.0052 | IoU: 0.6672 | dice: 0.8650 | dice_neg: 0.9492 | dice_pos: 0.7772
# Starting epoch: 105 | phase: val | ⏰: 15:32:16
# Loss: 0.0118 | IoU: 0.5458 | dice: 0.8004 | dice_neg: 0.9394 | dice_pos: 0.6657
#
# Starting epoch: 106 | phase: train | ⏰: 15:33:51
# Loss: 0.0052 | IoU: 0.6642 | dice: 0.8654 | dice_neg: 0.9564 | dice_pos: 0.7763
# Starting epoch: 106 | phase: val | ⏰: 15:48:12
# Loss: 0.0099 | IoU: 0.5792 | dice: 0.8232 | dice_neg: 0.9401 | dice_pos: 0.6985
#
# Starting epoch: 107 | phase: train | ⏰: 15:49:47
# Loss: 0.0052 | IoU: 0.6656 | dice: 0.8660 | dice_neg: 0.9505 | dice_pos: 0.7780
# Starting epoch: 107 | phase: val | ⏰: 16:04:06
# Loss: 0.0095 | IoU: 0.5894 | dice: 0.8260 | dice_neg: 0.9413 | dice_pos: 0.7062
#
# Starting epoch: 108 | phase: train | ⏰: 16:05:41
# Loss: 0.0052 | IoU: 0.6664 | dice: 0.8664 | dice_neg: 0.9565 | dice_pos: 0.7784
# Starting epoch: 108 | phase: val | ⏰: 16:19:59
# Loss: 0.0094 | IoU: 0.5869 | dice: 0.8272 | dice_neg: 0.9503 | dice_pos: 0.6983
#
# Starting epoch: 109 | phase: train | ⏰: 16:21:34
# Loss: 0.0052 | IoU: 0.6635 | dice: 0.8659 | dice_neg: 0.9568 | dice_pos: 0.7741
# Starting epoch: 109 | phase: val | ⏰: 16:35:53
# Loss: 0.0097 | IoU: 0.5832 | dice: 0.8232 | dice_neg: 0.9306 | dice_pos: 0.7021
#
# Starting epoch: 110 | phase: train | ⏰: 16:37:28
# Loss: 0.0052 | IoU: 0.6669 | dice: 0.8645 | dice_neg: 0.9563 | dice_pos: 0.7777
# Starting epoch: 110 | phase: val | ⏰: 16:51:47
# Loss: 0.0095 | IoU: 0.5904 | dice: 0.8246 | dice_neg: 0.9489 | dice_pos: 0.7121
#
# Starting epoch: 111 | phase: train | ⏰: 16:53:21
# Loss: 0.0051 | IoU: 0.6651 | dice: 0.8662 | dice_neg: 0.9543 | dice_pos: 0.7769
# Starting epoch: 111 | phase: val | ⏰: 17:07:38
# Loss: 0.0095 | IoU: 0.5855 | dice: 0.8200 | dice_neg: 0.9366 | dice_pos: 0.7096
#
# Starting epoch: 112 | phase: train | ⏰: 17:09:12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-05f46443fc03> in <module>
#       1 model_trainer = Trainer(model)
# ----> 2 model_trainer.start()
#
# <ipython-input-13-ebabfd62f862> in start(self)
#      77     def start(self):
#      78         for epoch in range(self.num_epochs):
# ---> 79             self.iterate(epoch, "train")
#      80             state = {
#      81                 "epoch": epoch,
#
# <ipython-input-13-ebabfd62f862> in iterate(self, epoch, phase)
#      65             running_loss += loss.item()
#      66             outputs = outputs.detach().cpu()
# ---> 67             meter.update(targets, outputs)
#      68 #             tk0.set_postfix(loss=(running_loss / ((itr + 1))))
#      69         epoch_loss = (running_loss * self.accumulation_steps) / total_batches
#
# <ipython-input-7-66816012bf6e> in update(self, targets, outputs)
#      49     def update(self, targets, outputs):
#      50         probs = torch.sigmoid(outputs)
# ---> 51         dice, dice_neg, dice_pos, _, _ = metric(probs, targets, self.base_threshold)
#      52         self.base_dice_scores.append(dice)
#      53         self.dice_pos_scores.append(dice_pos)
#
# <ipython-input-7-66816012bf6e> in metric(probability, truth, threshold, reduction)
#      15
#      16         p = (probability > threshold).float()
# ---> 17         t = (truth > 0.5).float()
#      18
#      19         t_sum = t.sum(-1)
#
# KeyboardInterrupt:

# %%
# PLOT TRAINING
losses = model_trainer.losses
dice_scores = model_trainer.dice_scores # overall dice
iou_scores = model_trainer.iou_scores

def plot(scores, name):
    plt.figure(figsize=(15,5))
    plt.plot(range(len(scores["train"])), scores["train"], label=f'train {name}')
    plt.plot(range(len(scores["train"])), scores["val"], label=f'val {name}')
    plt.title(f'{name} plot'); plt.xlabel('Epoch'); plt.ylabel(f'{name}');
    plt.legend(); 
    plt.show()

plot(losses, "BCE loss")
plot(dice_scores, "Dice score")
plot(iou_scores, "IoU score")

# %% [markdown]
# ## Test prediction and submission

# %% [markdown]
# This training and validation takes about ~400 minutes which exceeds Kaggle's GPU usage limit of 60 minutes, we won't be able to submit the `submission.csv` file generated from this kernel. So, for test prediction and submission I've written a separate [UNet inference kernel](https://www.kaggle.com/rishabhiitbhu/unet-pytorch-inference-kernel), make sure you add the `model.pth` file generated from this kernel as dataset to test inference kernel.

# %% [markdown]
# I've used resnet-18 architecture in this kernel. It scores ~0.89 on LB. Try to play around with other architectures of `segmenation_models.pytorch` and see what works best for you, let me know in the comments :) and do upvote if you liked this kernel, I need some medals too. 😬

# %% [markdown]
# ## Refrences:
#
# Few kernels from which I've borrowed some cod[](http://)e:
#
# * https://www.kaggle.com/amanooo/defect-detection-starter-u-net
# * https://www.kaggle.com/go1dfish/clear-mask-visualization-and-simple-eda
#
# A big thank you to all those who share their code on Kaggle, I'm nobody without you guys. I've learnt a lot from fellow kagglers, special shout-out to [@Abhishek](https://www.kaggle.com/abhishek), [@Yury](https://www.kaggle.com/deyury), [@Heng](https://www.kaggle.com/hengck23), [@Ekhtiar](https://www.kaggle.com/ekhtiar), [@lafoss](https://www.kaggle.com/iafoss), [@Siddhartha](https://www.kaggle.com/meaninglesslives), [@xhulu](https://www.kaggle.com/xhlulu), and the list goes on..
