# %% [markdown]
# <a href="https://colab.research.google.com/github/mobassir94/Severstal-Steel-Defect-Detection-Kaggle/blob/master/steel_defect_detection_se_resnext101_32x4d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
import keras
import matplotlib.pyplot as plt
from keras.layers import Dense,GlobalAveragePooling2D
from keras.applications import MobileNet
from keras.preprocessing import image
from keras.applications.mobilenet import preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.optimizers import Adam
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from keras.optimizers import SGD
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

from keras import optimizers
from google.colab import files
from google.colab import drive
from glob import glob
import os
import numpy as np

import tensorflow as tf


import os
import cv2
import pdb
import time
import warnings
import random
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook as tqdm
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader, Dataset, sampler
from matplotlib import pyplot as plt
from albumentations import (HorizontalFlip,VerticalFlip,Cutout,SmallestMaxSize,
                            ToGray, ShiftScaleRotate, Blur,Normalize, Resize, Compose, GaussNoise)
from albumentations.torch import ToTensor

warnings.filterwarnings("ignore")
seed = 69
random.seed(seed)
os.environ["PYTHONHASHSEED"] = str(seed)
np.random.seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
# Out:
# Using TensorFlow backend.

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2019.6.16)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (3.0.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.21.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.12.0)
# Requirement already satisfied: text-unidecode==1.2 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.8)

# %%
# !pip install -U -q kaggle
# !mkdir  /root/.kaggle
# Out:
#      |████████████████████████████████| 61kB 2.5MB/s
#   Building wheel for kaggle (setup.py) ... done

# %%
files.upload()
# !cp kaggle.json /root/.kaggle
# Out:
#      <input type="file" id="files-50b40bc1-e76c-45f4-8369-a916b8695b77" name="files[]" multiple disabled />
#      <output id="result-50b40bc1-e76c-45f4-8369-a916b8695b77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c severstal-steel-defect-detection
# Out:
# Downloading severstal-steel-defect-detection.zip to /content
#  99% 1.29G/1.29G [00:10<00:00, 96.7MB/s]
# 100% 1.29G/1.29G [00:10<00:00, 130MB/s]

# %%
# !unzip /content/severstal-steel-defect-detection.zip -d severstal-steel-defect-detection
# Out:
# Archive:  /content/severstal-steel-defect-detection.zip
#   inflating: severstal-steel-defect-detection/train_images.zip
#   inflating: severstal-steel-defect-detection/sample_submission.csv
#   inflating: severstal-steel-defect-detection/test_images.zip
#   inflating: severstal-steel-defect-detection/train.csv

# %%
os.remove('severstal-steel-defect-detection.zip')

# %% [markdown]
# **checking if pytorch is using the GPU?**

# %%
import torch

print(torch.cuda.current_device())

print(torch.cuda.device(0))

print(torch.cuda.device_count())

print(torch.cuda.get_device_name(0))

print(torch.cuda.is_available())
# Out:
# 0
# <torch.cuda.device object at 0x7f4dbb8ea7b8>
# 1
# Tesla K80
# True

# %% [markdown]
# *RLE-MAsk*

# %%
#https://www.kaggle.com/paulorzp/rle-functions-run-lenght-encode-decode
def mask2rle(img):
    '''
    img: numpy array, 1 -> mask, 0 -> background
    Returns run length as string formated
    '''
    pixels= img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def make_mask(row_id, df):
    '''Given a row index, return image_id and mask (256, 1600, 4) from the dataframe `df`'''
    fname = df.iloc[row_id].name
    labels = df.iloc[row_id][:4]
    masks = np.zeros((256, 1600, 4), dtype=np.float32) # float32 is V.Imp
    # 4:class 1～4 (ch:0～3)

    for idx, label in enumerate(labels.values):
        if label is not np.nan:
            label = label.split(" ")
            positions = map(int, label[0::2])
            length = map(int, label[1::2])
            mask = np.zeros(256 * 1600, dtype=np.uint8)
            for pos, le in zip(positions, length):
                mask[pos:(pos + le)] = 1
            masks[:, :, idx] = mask.reshape(256, 1600, order='F')
    return fname, masks

# %% [markdown]
# **DataLoader**

# %%
class SteelDataset(Dataset):
    def __init__(self, df, data_folder, mean, std, phase):
        self.df = df
        self.root = data_folder
        self.mean = mean
        self.std = std
        self.phase = phase
        self.transforms = get_transforms(phase, mean, std)
        self.fnames = self.df.index.tolist()

    def __getitem__(self, idx):
        image_id, mask = make_mask(idx, self.df)
        image_path = os.path.join(self.root, "train_images",  image_id)
        img = cv2.imread(image_path)
        augmented = self.transforms(image=img, mask=mask)
        img = augmented['image']
        mask = augmented['mask'] # 1x256x1600x4
        mask = mask[0].permute(2, 0, 1) # 1x4x256x1600
        return img, mask

    def __len__(self):
        return len(self.fnames)


def get_transforms(phase, mean, std):
    list_transforms = []
    if phase == "train":
        list_transforms.extend(
            [
            HorizontalFlip(p=0.5), # only horizontal flip as of now
            #VerticalFlip(p = 0.5),
            Blur(),
            Cutout(),
            #ShiftScaleRotate(),
            #SmallestMaxSize(),
            ToGray(),
            ]
        )
    list_transforms.extend(
        [
            Normalize(mean=mean, std=std, p=1),
            ToTensor(),
        ]
    )
    list_trfms = Compose(list_transforms)
    return list_trfms

def provider(
    data_folder,
    df_path,
    phase,
    mean=None,
    std=None,
    batch_size=16,
    num_workers=4,
):
    '''Returns dataloader for the model training'''
    df = pd.read_csv(df_path)
    # https://www.kaggle.com/amanooo/defect-detection-starter-u-net
    df['ImageId'], df['ClassId'] = zip(*df['ImageId_ClassId'].str.split('_'))
    df['ClassId'] = df['ClassId'].astype(int)
    df = df.pivot(index='ImageId',columns='ClassId',values='EncodedPixels')
    df['defects'] = df.count(axis=1)
    
    train_df, val_df = train_test_split(df, test_size=0.15, stratify=df["defects"], random_state=2019)
    df = train_df if phase == "train" else val_df
    image_dataset = SteelDataset(df, data_folder, mean, std, phase)
    dataloader = DataLoader(
        image_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        pin_memory=True,
        shuffle=True,   
    )

    return dataloader

# %% [markdown]
# **SomeUtility**

# %%
def predict(X, threshold):
    '''X is sigmoid output of the model'''
    X_p = np.copy(X)
    preds = (X_p > threshold).astype('uint8')
    return preds

def metric(probability, truth, threshold=0.5, reduction='none'):
    '''Calculates dice of positive and negative images seperately'''
    '''probability and truth must be torch tensors'''
    batch_size = len(truth)
    with torch.no_grad():
        probability = probability.view(batch_size, -1)
        truth = truth.view(batch_size, -1)
        assert(probability.shape == truth.shape)

        p = (probability > threshold).float()
        t = (truth > 0.5).float()

        t_sum = t.sum(-1)
        p_sum = p.sum(-1)
        neg_index = torch.nonzero(t_sum == 0)
        pos_index = torch.nonzero(t_sum >= 1)

        dice_neg = (p_sum == 0).float()
        dice_pos = 2 * (p*t).sum(-1)/((p+t).sum(-1))

        dice_neg = dice_neg[neg_index]
        dice_pos = dice_pos[pos_index]
        dice = torch.cat([dice_pos, dice_neg])

        dice_neg = np.nan_to_num(dice_neg.mean().item(), 0)
        dice_pos = np.nan_to_num(dice_pos.mean().item(), 0)
        dice = dice.mean().item()

        num_neg = len(neg_index)
        num_pos = len(pos_index)

    return dice, dice_neg, dice_pos, num_neg, num_pos

class Meter:
    '''A meter to keep track of iou and dice scores throughout an epoch'''
    def __init__(self, phase, epoch):
        self.base_threshold = 0.8 # <<<<<<<<<<< here's the threshold
        self.base_dice_scores = []
        self.dice_neg_scores = []
        self.dice_pos_scores = []
        self.iou_scores = []

    def update(self, targets, outputs):
        probs = torch.sigmoid(outputs)
        dice, dice_neg, dice_pos, _, _ = metric(probs, targets, self.base_threshold)
        self.base_dice_scores.append(dice)
        self.dice_pos_scores.append(dice_pos)
        self.dice_neg_scores.append(dice_neg)
        preds = predict(probs, self.base_threshold)
        iou = compute_iou_batch(preds, targets, classes=[1])
        self.iou_scores.append(iou)

    def get_metrics(self):
        dice = np.mean(self.base_dice_scores)
        dice_neg = np.mean(self.dice_neg_scores)
        dice_pos = np.mean(self.dice_pos_scores)
        dices = [dice, dice_neg, dice_pos]
        iou = np.nanmean(self.iou_scores)
        return dices, iou

def epoch_log(phase, epoch, epoch_loss, meter, start):
    '''logging the metrics at the end of an epoch'''
    dices, iou = meter.get_metrics()
    dice, dice_neg, dice_pos = dices
    print("Loss: %0.4f | IoU: %0.4f | dice: %0.4f | dice_neg: %0.4f | dice_pos: %0.4f" % (epoch_loss, iou, dice, dice_neg, dice_pos))
    return dice, iou

def compute_ious(pred, label, classes, ignore_index=255, only_present=True):
    '''computes iou for one ground truth mask and predicted mask'''
    pred[label == ignore_index] = 0
    ious = []
    for c in classes:
        label_c = label == c
        if only_present and np.sum(label_c) == 0:
            ious.append(np.nan)
            continue
        pred_c = pred == c
        intersection = np.logical_and(pred_c, label_c).sum()
        union = np.logical_or(pred_c, label_c).sum()
        if union != 0:
            ious.append(intersection / union)
    return ious if ious else [1]

def compute_iou_batch(outputs, labels, classes=None):
    '''computes mean iou for a batch of ground truth masks and predicted masks'''
    ious = []
    preds = np.copy(outputs) # copy is imp
    labels = np.array(labels) # tensor to np
    for pred, label in zip(preds, labels):
        ious.append(np.nanmean(compute_ious(pred, label, classes)))
    iou = np.nanmean(ious)
    return iou

# %%
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
# Out:
# Collecting git+https://github.com/qubvel/segmentation_models.pytorch
#   Cloning https://github.com/qubvel/segmentation_models.pytorch to /tmp/pip-req-build-apxbxr3h
#   Running command git clone -q https://github.com/qubvel/segmentation_models.pytorch /tmp/pip-req-build-apxbxr3h
# Requirement already satisfied: torchvision<=0.4.0,>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from segmentation-models-pytorch==0.0.3) (0.3.0)
# Collecting pretrainedmodels==0.7.4 (from segmentation-models-pytorch==0.0.3)
#   Downloading https://files.pythonhosted.org/packages/84/0e/be6a0e58447ac16c938799d49bfb5fb7a80ac35e137547fc6cee2c08c4cf/pretrainedmodels-0.7.4.tar.gz (58kB)
#      |████████████████████████████████| 61kB 2.4MB/s
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision<=0.4.0,>=0.2.2->segmentation-models-pytorch==0.0.3) (4.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision<=0.4.0,>=0.2.2->segmentation-models-pytorch==0.0.3) (1.16.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision<=0.4.0,>=0.2.2->segmentation-models-pytorch==0.0.3) (1.12.0)
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from torchvision<=0.4.0,>=0.2.2->segmentation-models-pytorch==0.0.3) (1.1.0)
# Collecting munch (from pretrainedmodels==0.7.4->segmentation-models-pytorch==0.0.3)
#   Downloading https://files.pythonhosted.org/packages/68/f4/260ec98ea840757a0da09e0ed8135333d59b8dfebe9752a365b04857660a/munch-2.3.2.tar.gz
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch==0.0.3) (4.28.1)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.1.1->torchvision<=0.4.0,>=0.2.2->segmentation-models-pytorch==0.0.3) (0.46)
# Building wheels for collected packages: segmentation-models-pytorch, pretrainedmodels, munch
#   Building wheel for segmentation-models-pytorch (setup.py) ... done
#   Created wheel for segmentation-models-pytorch: filename=segmentation_models_pytorch-0.0.3-cp36-none-any.whl size=27374 sha256=9324b7026a48e3199160cc21d87ed45f7bd99ca4e5884b1c556343b2ebb035db
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y92vrz3f/wheels/79/3f/09/1587a252e0314d26ad242d6d2e165622ab95c95e5cfe4b942c
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-cp36-none-any.whl size=60963 sha256=9abaf0f4b07f64881719c9b72daabc61e5e1b835db7eb898519227814d8c510b
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
#   Building wheel for munch (setup.py) ... done
#   Created wheel for munch: filename=munch-2.3.2-py2.py3-none-any.whl size=6614 sha256=ddc5fbe64501b0364eacf1a95cb13e06fd682c1603066466d31e6298cc2eebc0
#   Stored in directory: /root/.cache/pip/wheels/db/bf/bc/06a3e1bfe0ab27d2e720ceb3cff3159398d92644c0cec2c125
# Successfully built segmentation-models-pytorch pretrainedmodels munch
# Installing collected packages: munch, pretrainedmodels, segmentation-models-pytorch
# Successfully installed munch-2.3.2 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.0.3

# %%
import segmentation_models_pytorch as smp

# %%
model = smp.Unet("se_resnext101_32x4d", encoder_weights="imagenet", classes=4, activation=None)
# Out:
# Downloading: "http://data.lip6.fr/cadene/pretrainedmodels/se_resnext101_32x4d-3b2fe3d8.pth" to /root/.cache/torch/checkpoints/se_resnext101_32x4d-3b2fe3d8.pth
# 100%|██████████| 196466866/196466866 [09:13<00:00, 355127.56it/s]

# %% [markdown]
# **Train and validation**

# %%
# For saving model in google drive
drive.mount('/content/gdrive')

mymodel = 'resnet101.pth'

path = F"/content/gdrive/My Drive/{mymodel}"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **RADAM**

# %%
import math
import torch
from torch.optim.optimizer import Optimizer, required

class RAdam(Optimizer):

    def __init__(self, params, lr=1e-3, betas=(0.9, 0.999), eps=1e-8, weight_decay=0):
        defaults = dict(lr=lr, betas=betas, eps=eps, weight_decay=weight_decay)
        self.buffer = [[None, None, None] for ind in range(10)]
        super(RAdam, self).__init__(params, defaults)

    def __setstate__(self, state):
        super(RAdam, self).__setstate__(state)

    def step(self, closure=None):

        loss = None
        if closure is not None:
            loss = closure()

        for group in self.param_groups:

            for p in group['params']:
                if p.grad is None:
                    continue
                grad = p.grad.data.float()
                if grad.is_sparse:
                    raise RuntimeError('RAdam does not support sparse gradients')

                p_data_fp32 = p.data.float()

                state = self.state[p]

                if len(state) == 0:
                    state['step'] = 0
                    state['exp_avg'] = torch.zeros_like(p_data_fp32)
                    state['exp_avg_sq'] = torch.zeros_like(p_data_fp32)
                else:
                    state['exp_avg'] = state['exp_avg'].type_as(p_data_fp32)
                    state['exp_avg_sq'] = state['exp_avg_sq'].type_as(p_data_fp32)

                exp_avg, exp_avg_sq = state['exp_avg'], state['exp_avg_sq']
                beta1, beta2 = group['betas']

                exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
                exp_avg.mul_(beta1).add_(1 - beta1, grad)

                state['step'] += 1
                buffered = self.buffer[int(state['step'] % 10)]
                if state['step'] == buffered[0]:
                    N_sma, step_size = buffered[1], buffered[2]
                else:
                    buffered[0] = state['step']
                    beta2_t = beta2 ** state['step']
                    N_sma_max = 2 / (1 - beta2) - 1
                    N_sma = N_sma_max - 2 * state['step'] * beta2_t / (1 - beta2_t)
                    buffered[1] = N_sma

                    # more conservative since it's an approximated value
                    if N_sma >= 5:
                        step_size = group['lr'] * math.sqrt((1 - beta2_t) * (N_sma - 4) / (N_sma_max - 4) * (N_sma - 2) / N_sma * N_sma_max / (N_sma_max - 2)) / (1 - beta1 ** state['step'])
                    else:
                        step_size = group['lr'] / (1 - beta1 ** state['step'])
                    buffered[2] = step_size

                if group['weight_decay'] != 0:
                    p_data_fp32.add_(-group['weight_decay'] * group['lr'], p_data_fp32)

                # more conservative since it's an approximated value
                if N_sma >= 5:            
                    denom = exp_avg_sq.sqrt().add_(group['eps'])
                    p_data_fp32.addcdiv_(-step_size, exp_avg, denom)
                else:
                    p_data_fp32.add_(-step_size, exp_avg)

                p.data.copy_(p_data_fp32)

        return loss

# %%
class Trainer(object):
    '''This class takes care of training and validation of our model'''
    def __init__(self, model):
        self.num_workers = 6
        self.batch_size = {"train": 4, "val": 4}
        self.accumulation_steps = 32 // self.batch_size['train']
        self.lr = 5e-4
        self.num_epochs = 15
        self.best_loss = float("inf")
        self.phases = ["train", "val"]
        self.device = torch.device("cuda:0")
        torch.set_default_tensor_type("torch.cuda.FloatTensor")
        self.net = model
        self.criterion = torch.nn.BCEWithLogitsLoss()
        self.optimizer = RAdam(model.parameters(), lr=self.lr)
        self.scheduler = ReduceLROnPlateau(self.optimizer, mode="min", patience=3, verbose=True)
        self.net = self.net.to(self.device)
        cudnn.benchmark = True
        self.dataloaders = {
            phase: provider(
                data_folder=data_folder,
                df_path=train_df_path,
                phase=phase,
                mean=(0.485, 0.456, 0.406),
                std=(0.229, 0.224, 0.225),
                batch_size=self.batch_size[phase],
                num_workers=self.num_workers,
            )
            for phase in self.phases
        }
        self.losses = {phase: [] for phase in self.phases}
        self.iou_scores = {phase: [] for phase in self.phases}
        self.dice_scores = {phase: [] for phase in self.phases}
        
    def forward(self, images, targets):
        images = images.to(self.device)
        masks = targets.to(self.device)
        outputs = self.net(images)
        loss = self.criterion(outputs, masks)
        return loss, outputs

    def iterate(self, epoch, phase):
        meter = Meter(phase, epoch)
        start = time.strftime("%H:%M:%S")
        print(f"Starting epoch: {epoch} | phase: {phase} | ⏰: {start}")
        batch_size = self.batch_size[phase]
        self.net.train(phase == "train")
        dataloader = self.dataloaders[phase]
        running_loss = 0.0
        total_batches = len(dataloader)
#         tk0 = tqdm(dataloader, total=total_batches)
        self.optimizer.zero_grad()
        for itr, batch in enumerate(dataloader): # replace `dataloader` with `tk0` for tqdm
            images, targets = batch
            loss, outputs = self.forward(images, targets)
            loss = loss / self.accumulation_steps
            if phase == "train":
                loss.backward()
                if (itr + 1 ) % self.accumulation_steps == 0:
                    self.optimizer.step()
                    self.optimizer.zero_grad()
            running_loss += loss.item()
            outputs = outputs.detach().cpu()
            meter.update(targets, outputs)
#             tk0.set_postfix(loss=(running_loss / ((itr + 1))))
        epoch_loss = (running_loss * self.accumulation_steps) / total_batches
        dice, iou = epoch_log(phase, epoch, epoch_loss, meter, start)
        self.losses[phase].append(epoch_loss)
        self.dice_scores[phase].append(dice)
        self.iou_scores[phase].append(iou)
        torch.cuda.empty_cache()
        return epoch_loss

    def start(self):
        for epoch in range(self.num_epochs):
            self.iterate(epoch, "train")
            state = {
                "epoch": epoch,
                "best_loss": self.best_loss,
                "state_dict": self.net.state_dict(),
                "optimizer": self.optimizer.state_dict(),
            }
            with torch.no_grad():
                val_loss = self.iterate(epoch, "val")
                self.scheduler.step(val_loss)
            if val_loss < self.best_loss:
                print("******** New optimal found, saving state ********")
                state["best_loss"] = self.best_loss = val_loss
                #torch.save(state, "./model.pth")
                torch.save(state, path)
            print()

# %% [markdown]
# **Paths**

# %%
# !unzip /content/severstal-steel-defect-detection/test_images.zip -d /content/severstal-steel-defect-detection/test_images
# !unzip /content/severstal-steel-defect-detection/train_images.zip -d /content/severstal-steel-defect-detection/train_images
# Out:
# Archive:  /content/severstal-steel-defect-detection/test_images.zip
#   inflating: /content/severstal-steel-defect-detection/test_images/1804f41eb.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/c90f155dd.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/e0b422958.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/a631d53aa.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/d01da361f.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/86fe3cf8c.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/54eb4b690.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/2efa6b22f.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/d6128fbfc.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/f625f93a1.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/499a9893b.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/4c5671c92.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/f05581eef.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/d04a7fb6c.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/7dd388867.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/7dd7fc396.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/2a830069f.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/44d86ff71.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/6d29df253.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/c86f91dbf.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/674ecec48.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/541e5bfec.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/67fd6ce4d.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/9d81c8973.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/d89072b2f.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/443d3ddd0.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/d0d0681d3.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/2233caaaf.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/e237a3954.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/492e3ed43.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/c1fac7911.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/28c2b84a3.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/ab3a9a988.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/84e348664.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/95eb51548.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/6a45da8e9.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/0e39b3fcc.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/1c38cbe2a.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/e120be595.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/ac290f376.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/4d429c29f.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/06dc73f58.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/ea2ae621a.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/0384b28ff.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/3b2a280dd.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/690fbb138.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/cdfb634a5.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/335d78292.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/54a757589.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/938120712.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/7e104caad.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/22ef16f72.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/837f2703c.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/dd7f00ee2.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/e4612d7c4.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/f14eb3bba.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/204b55ba0.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/9542ddbff.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/3a3b76e0a.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/171ff4d5d.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/b461a25f2.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/b7018c2a5.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/ec82d6165.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/d249e6983.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/ba1196257.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/f131a6bfb.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/56d707102.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/8ef00bf22.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/3d060ac2d.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/56d3153f9.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/faeac05d8.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/304492df5.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/7979e93cd.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/225028fc0.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/cd75780c0.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/8bc3d26cb.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/71fa60ddf.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/4e8309017.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/c832f2a91.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/7be8cd98d.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/6b9d0b108.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/735aed3ac.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/14f307da8.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images/0d0d892af.jpg
#   inflating: /content/severstal-steel-defect-detection/test_images
510_145159765.jpg', 'Google Photos', 'tmi dekhso.gdoc', 'IMG_20170630_225418594.jpg', 'IMG_20170630_225522784.jpg', 'IMG_20170630_225653171.jpg', 'IMG_20170630_225722372.jpg', 'IMG_20170321_115850.jpg', 'IMG_20170718_010142780.jpg', 'old me', 'test folder', 'share', 'paul2017.pdf', 'Desktop.zip', 'hybrid pcf in chemical sensing.pdf', 'Screenshot_20171029-233519.png', 'Softwares', 'RATON-K.M.S-2017.rar', '.facebook_1521010774481.jpg', 'bristy shonamoni i miss you!.gdoc', 'Security 1.rar', '10th NOVEMBER 2016', 'internal', 'MyHeartBRISTYDOLL', 'personal', 'recording', "Shonamoni's Eye Analogy", 'RESULTS', 'My_Personal_Data', 'IMG_20170807_212247.jpg', "Bristy ShOnamonI I love you..!! :'(.gdoc", "i'm still loving you heart :'(.gdoc", 'bristy amr khb ks2 hosse.gdoc', 'songs', 'temp', 'sharing', 'W10 Activator.zip', 'Copy of W10 Activator.zip', 'Colab Notebooks', 'Untitled Diagram.pdf', 'Books', 'gopalpur,dhanbari,nolua tour', 'Kushtia Tour', 'Practice.zip', 'Cox Bazar & Rangamati Tour 2019', 'MOBASSIRcv.pdf', 'MOBASSIRcv - mobassir hossen.pdf', 'MOBASSIRcv (1).pdf', '27544564_149112862464506_2186211692843411029_n_149112862464506.jpg', '0ld', 'presentation', 'VID_20190424_005701.mp4', 'Play Books Notes', 'tutorials', 'sreemangal tour', 'model.pth']

# %%
sample_submission_path = './severstal-steel-defect-detection/sample_submission.csv'
train_df_path = './severstal-steel-defect-detection/train.csv'
data_folder = "./severstal-steel-defect-detection/" 
test_data_folder =  './severstal-steel-defect-detection/test_images/'

# %%
model_trainer = Trainer(model)
model_trainer.start()
# Out:
# Starting epoch: 0 | phase: train | ⏰: 12:54:55
# Loss: 0.5979 | IoU: 0.0085 | dice: 0.2138 | dice_neg: 0.4097 | dice_pos: 0.0150
# Starting epoch: 0 | phase: val | ⏰: 14:55:26
# Loss: 0.4555 | IoU: 0.0000 | dice: 0.4571 | dice_neg: 0.8983 | dice_pos: 0.0000
# ******** New optimal found, saving state ********
#
# Starting epoch: 1 | phase: train | ⏰: 15:03:06
# Loss: 0.3956 | IoU: 0.0001 | dice: 0.3265 | dice_neg: 0.6353 | dice_pos: 0.0002
# Starting epoch: 1 | phase: val | ⏰: 17:02:34
# Loss: 0.3283 | IoU: 0.0000 | dice: 0.3682 | dice_neg: 0.7359 | dice_pos: 0.0001
# ******** New optimal found, saving state ********
#
# Starting epoch: 2 | phase: train | ⏰: 17:10:11

# %%
# PLOT TRAINING
losses = model_trainer.losses
dice_scores = model_trainer.dice_scores # overall dice
iou_scores = model_trainer.iou_scores

def plot(scores, name):
    plt.figure(figsize=(15,5))
    plt.plot(range(len(scores["train"])), scores["train"], label=f'train {name}')
    plt.plot(range(len(scores["train"])), scores["val"], label=f'val {name}')
    plt.title(f'{name} plot'); plt.xlabel('Epoch'); plt.ylabel(f'{name}');
    plt.legend(); 
    plt.show()

plot(losses, "BCE loss")
plot(dice_scores, "Dice score")
plot(iou_scores, "IoU score")
